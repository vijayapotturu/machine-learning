# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

nas_df = pd.read_csv('nas.csv')

print(nas_df.shape)
# Out:
# (8801, 64)

# %%
nas_df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu   ...     \
# 0            2.0   1 sibling       No      Illiterate   ...
# 1            2.0  3 siblings       No             NaN   ...
# 2            2.0  3 siblings       No  Degree & above   ...
# 3            2.0  3 siblings       No       Secondary   ...
# 4            2.0  2 siblings       No         Primary   ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
nas_df['Siblings'] = nas_df['Siblings'].apply(lambda x : x[0] if x.find("sibling") != -1 else x)

# %%
nas_df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language Siblings Handicap      Father.edu   ...     \
# 0            2.0        1       No      Illiterate   ...
# 1            2.0        3       No             NaN   ...
# 2            2.0        3       No  Degree & above   ...
# 3            2.0        3       No       Secondary   ...
# 4            2.0        2       No         Primary   ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
nas_df['Siblings'] = nas_df['Siblings'].apply(lambda x : x[0] if x.find("+") != -1 else x)

# %%
nas_df['Siblings'] = nas_df['Siblings'].apply(lambda x : 0 if x.find("child") != -1 else x)

# %%
nas_df['Siblings'] = nas_df['Siblings'].astype(str).astype(int)

# %%
nas_df.columns
# Out:
# Index(['STUID', 'State', 'District', 'Gender', 'Age', 'Category',
#        'Same.language', 'Siblings', 'Handicap', 'Father.edu', 'Mother.edu',
#        'Father.occupation', 'Mother.occupation', 'Below.poverty',
#        'Use.calculator', 'Use.computer', 'Use.Internet', 'Use.dictionary',
#        'Read.other.books', 'X..Books', 'Distance', 'Computer.use',
#        'Library.use', 'Like.school', 'Subjects', 'Give.Lang.HW',
#        'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW', 'Correct.Lang.HW',
#        'Correct.Math.HW', 'Correct.Scie.HW', 'Correct.SocS.HW',
#        'Help.in.Study', 'Private.tuition', 'English.is.difficult',
#        'Read.English', 'Dictionary.to.learn', 'Answer.English.WB',
#        'Answer.English.aloud', 'Maths.is.difficult', 'Solve.Maths',
#        'Solve.Maths.in.groups', 'Draw.geometry', 'Explain.answers',
#        'SocSci.is.difficult', 'Historical.excursions', 'Participate.in.SocSci',
#        'Small.groups.in.SocSci', 'Express.SocSci.views',
# ...

# %%
nas_df['Mother.edu'] = nas_df[~nas_df['Mother.edu'].isnull()]

# %%
nas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8801 entries, 0 to 8800
# Data columns (total 64 columns):
# STUID                     8801 non-null int64
# State                     8801 non-null object
# District                  8801 non-null int64
# Gender                    8799 non-null object
# Age                       8569 non-null object
# Category                  8232 non-null float64
# Same.language             8572 non-null float64
# Siblings                  8801 non-null int64
# Handicap                  8304 non-null object
# Father.edu                8147 non-null object
# Mother.edu                7950 non-null object
# Father.occupation         7761 non-null object
# Mother.occupation         6626 non-null object
# Below.poverty             7347 non-null object
# Use.calculator            6646 non-null object
# Use.computer              6646 non-null object
# Use.Internet              6646 non-null object
# Use.dictionary            6646 non-null object
# ...

# %%
#nas_df.sample(100).plot.scatter(x='Siblings', y='Mother.edu')
sns.catplot(x="Mother.edu", y="Siblings", data=nas_df);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-5f11d139b70b> in <module>()
#       1 #nas_df.sample(100).plot.scatter(x='Siblings', y='Mother.edu')
# ----> 2 sns.catplot(x="Mother.edu", y="Siblings", data=nas_df);
#
# AttributeError: module 'seaborn' has no attribute 'catplot'

# %%
import pandas as pd
cust_rating = pd.read_csv('https://query.data.world/s/ILc-P4llUraMaYN6N6Bdw7p6kUvHnj')

print(cust_rating.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1254 entries, 0 to 1253
# Data columns (total 5 columns):
# userID            1254 non-null object
# placeID           1254 non-null int64
# rating            1254 non-null int64
# food_rating       1254 non-null int64
# service_rating    1254 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 49.1+ KB
# None
#   userID  placeID  rating  food_rating  service_rating  avg_rating
# 0  U1077   135085       2            2               2         NaN
# 1  U1077   135038       2            2               1         NaN
# 2  U1077   132825       2            2               2         NaN
# 3  U1077   135060       1            2               2         NaN
# 4  U1068   135104       1            1               2         NaN
# 5  U1068   132740       0            0               0         NaN
# 6  U1068   132663       1            1               1         NaN
# 7  U1068   132732       0            0               0         NaN
# ...

# %%
cust_rating['avg_rating'] = round(cust_rating.iloc[:, [2,3,4]].mean(axis=1))
print(cust_rating.head(10))
# Out:
#   userID  placeID  rating  food_rating  service_rating  avg_rating
# 0  U1077   135085       2            2               2         2.0
# 1  U1077   135038       2            2               1         2.0
# 2  U1077   132825       2            2               2         2.0
# 3  U1077   135060       1            2               2         2.0
# 4  U1068   135104       1            1               2         1.0
# 5  U1068   132740       0            0               0         0.0
# 6  U1068   132663       1            1               1         1.0
# 7  U1068   132732       0            0               0         0.0
# 8  U1068   132630       1            1               1         1.0
# 9  U1067   132584       2            2               2         2.0
