# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="white")

curr_df = pd.read_csv('currencies.csv')

print(curr_df.shape)
# Out:
# (11, 52)

# %%
curr_df.head()
# Out:
#         Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0  July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1  July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2  July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3  July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4  July 08, 2016       9.31350  1.25797       140.510              1.07261
#
#    U.S. Dollar  Algerian Dinar  Australian Dollar  Bahrain Dinar  \
# 0      1.39596             NaN            1.87126       0.524882
# 1      1.39684         154.063            1.85825       0.525213
# 2      1.39286         154.094            1.87313       0.523717
# 3      1.39316         153.957            1.85236       0.523829
# 4      1.39257         154.062            1.85974       0.523607
#
#    Botswana Pula       ...        South African Rand  Sri Lanka Rupee  \
# ...

# %%
plt.figure(figsize=(30, 26))
plt.matshow(curr_df.corr())

# %%
def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);
    
plot_corr(curr_df)

# %%
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Abalone Feature Correlation')
    labels=['Sex','Length','Diam','Height','Whole','Shucked','Viscera','Shell','Rings',]
    ax1.set_xticklabels(labels,fontsize=6)
    ax1.set_yticklabels(labels,fontsize=6)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=[.75,.8,.85,.90,.95,1])
    plt.show()

correlation_matrix(curr_df)

# %%
cor = curr_df.corr()
sns.heatmap(cor, 
            xticklabels=cor.columns.values,
            yticklabels=cor.columns.values)

# %%
curr_df.corr().style.background_gradient().set_precision(2)
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_503df994_db96_11e8_a79b_ba0040195301row0_col0 {
#             background-color:  #023858;
#         }    #T_503df994_db96_11e8_a79b_ba0040195301row0_col1 {
#             background-color:  #6ba5cd;
#         }    #T_503df994_db96_11e8_a79b_ba0040195301row0_col2 {
#             background-color:  #5a9ec9;
#         }    #T_503df994_db96_11e8_a79b_ba0040195301row0_col3 {
#             background-color:  #5c9fc9;
#         }    #T_503df994_db96_11e8_a79b_ba0040195301row0_col4 {
#             background-color:  #4697c4;
#         }    #T_503df994_db96_11e8_a79b_ba0040195301row0_col5 {
#             background-color:  #04588a;
#         }    #T_503df994_db96_11e8_a79b_ba0040195301row0_col6 {
#             background-color:  #88b1d4;
#         }    #T_503df994_db96_11e8_a79b_ba0040195301row0_col7 {
# ...

# %%
plt.style.use('ggplot')

plt.imshow(curr_df.corr(), cmap=plt.cm.Reds, interpolation='nearest')
plt.colorbar()
tick_marks = [i for i in range(len(curr_df.columns))]
plt.xticks(tick_marks, curr_df.columns, rotation='vertical')
plt.yticks(tick_marks, curr_df.columns)
plt.show()
