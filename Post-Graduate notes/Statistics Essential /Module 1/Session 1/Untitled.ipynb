# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# the commonly used alias for seaborn is sns
import seaborn as sns

# set a seaborn style of your taste
sns.set_style("whitegrid")

# %%
student_df = pd.read_csv("sample.csv", delimiter=',', encoding="utf-8-sig")

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 9 columns):
# YearsOfExp        199 non-null object
# CompanyName       198 non-null object
# Title             196 non-null object
# Field of Study    199 non-null object
# Major             197 non-null object
# School Name       199 non-null object
# Gender            197 non-null object
# City              180 non-null object
# State             114 non-null object
# dtypes: object(9)
# memory usage: 14.1+ KB

# %%
student_df.head()
# Out:
#   YearsOfExp        CompanyName  \
# 0          5            PhonePe
# 1        10+  arrow electronics
# 2          7   General Electric
# 3          8             Vmware
# 4        10+               CABI
#
#                                             Title  \
# 0                            Mobile App Developer
# 1                                       Tech Lead
# 2  lead engineer, intellectual property analytics
# 3                            Full Stack Developer
# 4                                             CTO
#
#                            Field of Study   Major  \
# 0                 Electronics Engineering     B.E
# 1  Specialization In Industrial Chemistry     BSc
# 2    Electronics & Electrical Engineering  B.Tech
# 3          Computer Science / Engineering     B.E
# 4          Computer Science / Engineering     B.E
#
#                                          School Name Gender      City   \
# 0  D J Sanghvi College of Engineering Mumbai Univ...   Male  Bengaluru
# ...

# %%
student_df = student_df.dropna(how='any',axis=0)

# %%
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113 entries, 0 to 196
# Data columns (total 9 columns):
# YearsOfExp        113 non-null object
# CompanyName       113 non-null object
# Title             113 non-null object
# Field of Study    113 non-null object
# Major             113 non-null object
# School Name       113 non-null object
# Gender            113 non-null object
# City              113 non-null object
# State             113 non-null object
# dtypes: object(9)
# memory usage: 8.8+ KB

# %%
student_df.isnull().head()
# Out:
#     YearsOfExp  CompanyName  Title  Field of Study  Major  School Name  \
# 0        False        False  False           False  False        False
# 11       False        False  False           False  False        False
# 14       False        False  False           False  False        False
# 16       False        False  False           False  False        False
# 19       False        False  False           False  False        False
#
#     Gender  City   State
# 0    False  False  False
# 11   False  False  False
# 14   False  False  False
# 16   False  False  False
# 19   False  False  False

# %%
student_df.isnull().sum()
# Out:
# YearsOfExp        0
# CompanyName       0
# Title             0
# Field of Study    0
# Major             0
# School Name       0
# Gender            0
# City              0
# State             0
# dtype: int64

# %%
student_df.isnull().any()
# Out:
# YearsOfExp        False
# CompanyName       False
# Title             False
# Field of Study    False
# Major             False
# School Name       False
# Gender            False
# City              False
# State             False
# dtype: bool

# %%
round(100*(student_df.isnull().sum()/len(student_df.index)), 2)
# Out:
# YearsOfExp        0.0
# CompanyName       0.0
# Title             0.0
# Field of Study    0.0
# Major             0.0
# School Name       0.0
# Gender            0.0
# City              0.0
# State             0.0
# dtype: float64

# %%
student_df[student_df.isnull().sum(axis=1) > 2]
# Out:
# Empty DataFrame
# Columns: [YearsOfExp, CompanyName, Title, Field of Study, Major, School Name, Gender, City , State]
# Index: []

# %%
student_df.head()
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113 entries, 0 to 196
# Data columns (total 9 columns):
# YearsOfExp        113 non-null object
# CompanyName       113 non-null object
# Title             113 non-null object
# Field of Study    113 non-null object
# Major             113 non-null object
# School Name       113 non-null object
# Gender            113 non-null object
# City              113 non-null object
# State             113 non-null object
# dtypes: object(9)
# memory usage: 8.8+ KB

# %%
student_df.City.tail()
# Out:
# 190      Acworth
# 191    Hyderabad
# 192       Dublin
# 194    Bengaluru
# 196    Bangalore
# Name: City, dtype: object

# %%
df = student_df[(student_df['City'].astype(str) == 'Bengaluru')]
len(df.index) / len(student_df.index) * 100
# Out:
# 47.78761061946903

# %%
student_df.groupby('City').head()
# Out:
#     YearsOfExp                                   CompanyName  \
# 0            5                                       PhonePe
# 11           8                                     Datazymes
# 14         10+                                   Expedia Inc
# 16           6             Deloitte Consulting India Pvt Ltd
# 19         10+                            Wipro Technologies
# 20         10+                                      Allstate
# 21           2                                         Nokia
# 22         10+                                   Informatica
# 23         10+                                     IMImobile
# 24           9                                  Boeing India
# 27         10+                            Target Corporation
# 28           4  Cognizant Technology Solutions India Pvt Ltd
# 29           8                            Unitedhealth Group
# 30           4   Lotus Wireless Technologies Private Limited
# ...
