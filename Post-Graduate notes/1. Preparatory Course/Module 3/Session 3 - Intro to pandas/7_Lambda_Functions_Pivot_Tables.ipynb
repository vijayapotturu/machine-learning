# %% [markdown]
# # Lambda Functions and Pivot Tables
#
# Until now, we have not made any changes or modifications to the data. In this section, we will:
# * Use lambda functions to create new and alter existing columns
# * Use pandas pivot tables as an alternative to ```df.groupby()``` to summarise data
#
# Let's first read all the files and create a ```master_df```.

# %%
# Loading libraries and files
import numpy as np
import pandas as pd

market_df = pd.read_csv("market_fact.csv")
customer_df = pd.read_csv("cust_dimen.csv")
product_df = pd.read_csv("prod_dimen.csv")
shipping_df = pd.read_csv("shipping_dimen.csv")
orders_df = pd.read_csv("orders_dimen.csv")

# Merging the dataframes to create a master_df
df_1 = pd.merge(market_df, customer_df, how='inner', on='Cust_id')
df_2 = pd.merge(df_1, product_df, how='inner', on='Prod_id')
df_3 = pd.merge(df_2, shipping_df, how='inner', on='Ship_id')
master_df = pd.merge(df_3, orders_df, how='inner', on='Ord_id')

master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 4  Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05              35
#
#     Profit  Shipping_Cost  Product_Base_Margin       ...         Region  \
# 0   -30.51           3.60                 0.56       ...           WEST
# 1  1148.90           2.50                 0.59       ...           WEST
# 2   -47.64           6.15                 0.37       ...           WEST
# 3    23.12           3.37                 0.57       ...        ONTARIO
# 4   -17.58           3.98                 0.56       ...           WEST
#
#   Customer_Segment Product_Category           Product_Sub_Category Order_ID_x  \
# 0        CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      36262
# 1        CORPORATE       TECHNOLOGY   TELEPHONES AND COMMUNICATION      36262
# 2        CORPORATE  OFFICE SUPPLIES                          PAPER      36262
# 3      HOME OFFICE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      37863
# 4         CONSUMER  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      53026
#
#      Ship_Mode   Ship_Date Order_ID_y  Order_Date  Order_Priority
# 0  REGULAR AIR  28-07-2010      36262  27-07-2010   NOT SPECIFIED
# 1  EXPRESS AIR  27-07-2010      36262  27-07-2010   NOT SPECIFIED
# 2  EXPRESS AIR  28-07-2010      36262  27-07-2010   NOT SPECIFIED
# 3  REGULAR AIR  26-02-2011      37863  24-02-2011            HIGH
# 4  REGULAR AIR  03-03-2012      53026  26-02-2012             LOW
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Lambda Functions
#
# Say you want to create a new column indicating whether a given order was profitable or not (1/0).
#
# You need to apply a function which returns 1 if Profit > 0, else 0. This can be easily done using the ```apply()``` method on a column of the dataframe.

# %%
# Create a function to be applied
def is_positive(x):
    return x > 0

# Create a new column
master_df['isProfitable'] = master_df['Profit'].apply(is_positive)
master_df.head()
master_df.drop(['is_profitable'],inplace=False,axis=1)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.69      0.00
# 2     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.02      0.03
# 3     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 4     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 5     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 6     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# 7     Ord_4143   Prod_6  SHP_5770  Cust_1417    901.32      0.10
# 8     Ord_4796  Prod_16  SHP_6686  Cust_1659     95.09      0.09
# 9     Ord_4796   Prod_6  SHP_6686  Cust_1659    122.09      0.04
# 10    Ord_4796  Prod_13  SHP_6687  Cust_1659    150.06      0.02
# 11    Ord_1854  Prod_16  SHP_2548   Cust_727    182.47      0.05
# 12    Ord_1854   Prod_6  SHP_2548   Cust_622    817.53      0.03
# 13    Ord_1854  Prod_17  SHP_2548   Cust_564     25.96      0.06
# 14    Ord_4506  Prod_16  SHP_6273  Cust_1544     92.02      0.07
# 15    Ord_4080  Prod_16  SHP_5688  Cust_1388    666.40      0.00
# 16    Ord_4080   Prod_7  SHP_5687  Cust_1388     10.62      0.07
# 17    Ord_4080   Prod_1  SHP_5689  Cust_1388    351.30      0.06
# 18    Ord_1551  Prod_16  SHP_2145   Cust_531    184.77      0.00
# 19    Ord_1579  Prod_16  SHP_2178   Cust_566    139.37      0.04
# 20    Ord_1579   Prod_6  SHP_2177   Cust_566     23.38      0.08
# 21    Ord_1579   Prod_1  SHP_2179   Cust_566   1221.62      0.01
# 22    Ord_1429  Prod_16  SHP_1976   Cust_510    539.06      0.05
# 23    Ord_2471  Prod_16  SHP_3386   Cust_965     90.93      0.05
# 24    Ord_2471  Prod_13  SHP_3386   Cust_965    125.95      0.00
# 25    Ord_2471   Prod_5  SHP_3385   Cust_965    129.50      0.02
# 26    Ord_2471   Prod_3  SHP_3384   Cust_965     61.43      0.09
# 27    Ord_2873  Prod_16  SHP_3957  Cust_1052    138.55      0.03
# 28    Ord_2873   Prod_2  SHP_3957  Cust_1052    451.44      0.10
# 29      Ord_43  Prod_16    SHP_56    Cust_34   9620.82      0.04
# ...        ...      ...       ...        ...       ...       ...
# 8369  Ord_5471   Prod_8  SHP_7644  Cust_1819    214.94      0.06
# 8370  Ord_5414   Prod_8  SHP_7559  Cust_1819   1383.20      0.01
# 8371  Ord_2795   Prod_8  SHP_3843  Cust_1025    596.56      0.04
# 8372  Ord_2175   Prod_8  SHP_2964   Cust_810    475.58      0.04
# 8373  Ord_5188  Prod_14  SHP_7252  Cust_1749   5177.40      0.06
# 8374  Ord_4941  Prod_14  SHP_6892  Cust_1680   6034.68      0.06
# 8375  Ord_2988  Prod_14  SHP_4132  Cust_1105   9262.35      0.09
# 8376    Ord_19  Prod_14    SHP_26    Cust_14  12028.23      0.01
# 8377  Ord_2437  Prod_14  SHP_3344   Cust_929   4667.28      0.09
# 8378  Ord_5448  Prod_14  SHP_7613  Cust_1797  17605.77      0.01
# 8379  Ord_4543  Prod_14  SHP_6324  Cust_1538  23949.51      0.00
# 8380  Ord_2439  Prod_14  SHP_3346   Cust_942  16468.55      0.08
# 8381   Ord_396  Prod_14   SHP_532   Cust_139   8662.34      0.00
# 8382   Ord_421  Prod_14   SHP_565   Cust_142  10791.38      0.08
# 8383  Ord_1334  Prod_14  SHP_1835   Cust_507    885.94      0.08
# 8384   Ord_432  Prod_14   SHP_578   Cust_138  23255.61      0.00
# 8385   Ord_388  Prod_14   SHP_519   Cust_138   2543.95      0.04
# 8386  Ord_3409  Prod_14  SHP_4725  Cust_1244  21205.50      0.10
# 8387  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 8388  Ord_3990  Prod_14  SHP_5550  Cust_1368   2600.44      0.03
# 8389   Ord_757  Prod_14  SHP_1034   Cust_231   6607.92      0.06
# 8390  Ord_1096  Prod_14  SHP_1512   Cust_423   2222.61      0.02
# 8391  Ord_5097  Prod_14  SHP_7119  Cust_1731  21046.74      0.04
# 0      SCISSORS, RULERS AND TRIMMERS      36262     REGULAR AIR  28-07-2010
# 1       TELEPHONES AND COMMUNICATION      36262     EXPRESS AIR  27-07-2010
# 2                              PAPER      36262     EXPRESS AIR  28-07-2010
# 3      SCISSORS, RULERS AND TRIMMERS      37863     REGULAR AIR  26-02-2011
# 4      SCISSORS, RULERS AND TRIMMERS      53026     REGULAR AIR  03-03-2012
# 5      SCISSORS, RULERS AND TRIMMERS      36992     EXPRESS AIR  09-12-2009
# 6      SCISSORS, RULERS AND TRIMMERS      13920     REGULAR AIR  10-10-2009
# 7                              PAPER      13920     EXPRESS AIR  11-10-2009
# 8      SCISSORS, RULERS AND TRIMMERS      55554     REGULAR AIR  17-11-2009
# 9                              PAPER      55554     REGULAR AIR  17-11-2009
# 10               PENS & ART SUPPLIES      55554     REGULAR AIR  19-11-2009
# 11     SCISSORS, RULERS AND TRIMMERS      48455     REGULAR AIR  03-06-2009
# 12                             PAPER      48455     REGULAR AIR  03-06-2009
# 13                   OFFICE MACHINES      48455     REGULAR AIR  03-06-2009
# 14     SCISSORS, RULERS AND TRIMMERS      19524     REGULAR AIR  15-01-2010
# 15     SCISSORS, RULERS AND TRIMMERS      43653     EXPRESS AIR  31-10-2012
# 16                      RUBBER BANDS      43653     REGULAR AIR  30-10-2012
# 17            STORAGE & ORGANIZATION      43653     REGULAR AIR  01-11-2012
# 18     SCISSORS, RULERS AND TRIMMERS      39330     EXPRESS AIR  18-07-2010
# 19     SCISSORS, RULERS AND TRIMMERS      43367     EXPRESS AIR  10-03-2010
# 20                             PAPER      43367     REGULAR AIR  12-03-2010
# 21            STORAGE & ORGANIZATION      43367     REGULAR AIR  09-03-2010
# 22     SCISSORS, RULERS AND TRIMMERS      20259     REGULAR AIR  25-05-2011
# 23     SCISSORS, RULERS AND TRIMMERS      36355     REGULAR AIR  03-12-2009
# 24               PENS & ART SUPPLIES      36355     REGULAR AIR  03-12-2009
# 25                OFFICE FURNISHINGS      36355     REGULAR AIR  02-12-2009
# 26    BINDERS AND BINDER ACCESSORIES      36355     EXPRESS AIR  02-12-2009
# 27     SCISSORS, RULERS AND TRIMMERS      18595     REGULAR AIR  02-02-2009
# 28                        APPLIANCES      18595     REGULAR AIR  02-02-2009
# 29     SCISSORS, RULERS AND TRIMMERS       6116     REGULAR AIR  22-03-2009
# ...                              ...        ...             ...         ...
# 8369            COMPUTER PERIPHERALS      48000     REGULAR AIR  14-08-2012
# 8370            COMPUTER PERIPHERALS      24802     REGULAR AIR  25-01-2009
# 8371            COMPUTER PERIPHERALS      52805     EXPRESS AIR  28-09-2011
# 8372            COMPUTER PERIPHERALS      47556     REGULAR AIR  27-07-2010
# 8373                 COPIERS AND FAX      29988  DELIVERY TRUCK  14-06-2009
# 8374                 COPIERS AND FAX      54917     REGULAR AIR  10-04-2010
# 8375                 COPIERS AND FAX      23616     REGULAR AIR  28-08-2012
# 8376                 COPIERS AND FAX       1761  DELIVERY TRUCK  25-12-2010
# 8377                 COPIERS AND FAX      30114     EXPRESS AIR  23-08-2010
# 8378                 COPIERS AND FAX      36357  DELIVERY TRUCK  15-01-2012
# 8379                 COPIERS AND FAX      23168     EXPRESS AIR  22-09-2010
# 8380                 COPIERS AND FAX      30725  DELIVERY TRUCK  29-12-2009
# 8381                 COPIERS AND FAX      24388  DELIVERY TRUCK  27-01-2011
# 8382                 COPIERS AND FAX      33763     REGULAR AIR  25-09-2010
# 8383                 COPIERS AND FAX       5444     REGULAR AIR  19-03-2011
# 8384                 COPIERS AND FAX      36677     REGULAR AIR  25-12-2009
# 8385                 COPIERS AND FAX      20033     REGULAR AIR  23-05-2010
# 8386                 COPIERS AND FAX      37124     REGULAR AIR  01-04-2012
# 8387                 COPIERS AND FAX      32932     REGULAR AIR  13-01-2010
# 8388                 COPIERS AND FAX      48128     EXPRESS AIR  12-04-2012
# 8389                 COPIERS AND FAX      20961     REGULAR AIR  16-01-2010
# 8390                 COPIERS AND FAX      38693     REGULAR AIR  21-06-2011
# 8391                 COPIERS AND FAX      21188     REGULAR AIR  23-09-2011
# 8392                 COPIERS AND FAX      22917     EXPRESS AIR  04-03-2009
# 8393                 COPIERS AND FAX      48800     REGULAR AIR  23-10-2010
# 8394                 COPIERS AND FAX      54214     EXPRESS AIR  05-01-2012
# 8395                 COPIERS AND FAX      52035     REGULAR AIR  30-11-2009
# 8396                 COPIERS AND FAX       5988     EXPRESS AIR  22-11-2010
# 8397                 COPIERS AND FAX      27616     REGULAR AIR  01-08-2012
# 8398                 COPIERS AND FAX      41895     REGULAR AIR  12-01-2011
#
#       Order_ID_y  Order_Date Order_Priority  isProfitable
# 0          36262  27-07-2010  NOT SPECIFIED         False
# 1          36262  27-07-2010  NOT SPECIFIED          True
# 2          36262  27-07-2010  NOT SPECIFIED         False
# 3          37863  24-02-2011           HIGH          True
# 4          53026  26-02-2012            LOW         False
# 5          36992  07-12-2009         MEDIUM          True
# 6          13920  09-10-2009       CRITICAL         False
# 7          13920  09-10-2009       CRITICAL          True
# 8          55554  16-11-2009       CRITICAL         False
# 9          55554  16-11-2009       CRITICAL         False
# 10         55554  16-11-2009       CRITICAL          True
# 11         48455  02-06-2009       CRITICAL         False
# 12         48455  02-06-2009       CRITICAL          True
# 13         48455  02-06-2009       CRITICAL         False
# 14         19524  14-01-2010       CRITICAL         False
# 15         43653  30-10-2012           HIGH          True
# 16         43653  30-10-2012           HIGH         False
# 17         43653  30-10-2012           HIGH          True
# 18         39330  17-07-2010       CRITICAL         False
# 19         43367  09-03-2010       CRITICAL          True
# 20         43367  09-03-2010       CRITICAL         False
# 21         43367  09-03-2010       CRITICAL         False
# 22         20259  24-05-2011       CRITICAL         False
# 23         36355  02-12-2009         MEDIUM         False
# 24         36355  02-12-2009         MEDIUM          True
# 25         36355  02-12-2009         MEDIUM          True
# 26         36355  02-12-2009         MEDIUM         False
# 27         18595  31-01-2009       CRITICAL          True
# 28         18595  31-01-2009       CRITICAL         False
# 29          6116  20-03-2009         MEDIUM         False
# ...          ...         ...            ...           ...
# 8369       48000  13-08-2012           HIGH          True
# 8370       24802  23-01-2009         MEDIUM         False
# 8371       52805  28-09-2011           HIGH          True
# 8372       47556  25-07-2010            LOW          True
# 8373       29988  12-06-2009           HIGH          True
# 8374       54917  09-04-2010           HIGH         False
# 8375       23616  28-08-2012  NOT SPECIFIED          True
# 8376        1761  23-12-2010           HIGH         False
# 8377       30114  16-08-2010            LOW         False
# 8378       36357  14-01-2012  NOT SPECIFIED         False
# 8379       23168  15-09-2010            LOW         False
# 8380       30725  28-12-2009         MEDIUM          True
# 8381       24388  26-01-2011       CRITICAL         False
# 8382       33763  23-09-2010  NOT SPECIFIED         False
# 8383        5444  17-03-2011       CRITICAL         False
# 8384       36677  23-12-2009            LOW         False
# 8385       20033  21-05-2010       CRITICAL         False
# 8386       37124  30-03-2012            LOW          True
# 8387       32932  09-01-2010            LOW          True
# 8388       48128  11-04-2012         MEDIUM         False
# 8389       20961  14-01-2010  NOT SPECIFIED          True
# 8390       38693  14-06-2011            LOW          True
# 8391       21188  21-09-2011       CRITICAL          True
# 8392       22917  01-03-2009         MEDIUM         False
# 8393       48800  22-10-2010  NOT SPECIFIED          True
# 8394       54214  02-01-2012         MEDIUM          True
# 8395       52035  27-11-2009           HIGH         False
# 8396        5988  21-11-2010  NOT SPECIFIED         False
# 8397       27616  30-07-2012            LOW         False
# 8398       41895  10-01-2011       CRITICAL         False
#
# [8399 rows x 23 columns]

# %% [markdown]
# The same can be done in just one line of code using lambda functions.

# %%
# Create a new column using a lambda function
master_df['is_profitable'] = master_df['Profit'].apply(lambda x: x > 1)
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 4  Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05              35
#
#     Profit  Shipping_Cost  Product_Base_Margin      ...        \
# 0   -30.51           3.60                 0.56      ...
# 1  1148.90           2.50                 0.59      ...
# 2   -47.64           6.15                 0.37      ...
# 3    23.12           3.37                 0.57      ...
# 4   -17.58           3.98                 0.56      ...
#
#   Product_Category           Product_Sub_Category Order_ID_x    Ship_Mode  \
# 0  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      36262  REGULAR AIR
# 1       TECHNOLOGY   TELEPHONES AND COMMUNICATION      36262  EXPRESS AIR
# 2  OFFICE SUPPLIES                          PAPER      36262  EXPRESS AIR
# 3  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      37863  REGULAR AIR
# 4  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS      53026  REGULAR AIR
#
#     Ship_Date Order_ID_y  Order_Date Order_Priority isProfitable  \
# 0  28-07-2010      36262  27-07-2010  NOT SPECIFIED        False
# 1  27-07-2010      36262  27-07-2010  NOT SPECIFIED         True
# 2  28-07-2010      36262  27-07-2010  NOT SPECIFIED        False
# 3  26-02-2011      37863  24-02-2011           HIGH         True
# 4  03-03-2012      53026  26-02-2012            LOW        False
#
#    is_profitable
# 0          False
# 1           True
# 2          False
# 3           True
# 4          False
#
# [5 rows x 24 columns]

# %% [markdown]
# Now you can use the new column to compare the percentage of profitable orders across groups.

# %%
# Comparing percentage of profitable orders across customer segments
by_segment = master_df.groupby('Customer_Segment')
by_segment.is_profitable.mean()
# Out:
# Customer_Segment
# CONSUMER          0.496058
# CORPORATE         0.477893
# HOME OFFICE       0.491142
# SMALL BUSINESS    0.491474
# Name: is_profitable, dtype: float64

# %%
# Comparing percentage of profitable orders across product categories
by_category = master_df.groupby('Product_Category')
by_category.is_profitable.mean()
# Out:
# Product_Category
# FURNITURE          0.464037
# OFFICE SUPPLIES    0.458134
# TECHNOLOGY         0.571913
# Name: is_profitable, dtype: float64

# %% [markdown]
# In FURNITURE, 46% orders are profitable, compared to 57% in TECHNOLOGY.

# %%
# You can also use apply and lambda to alter existing columns
# E.g. you want to see Profit as one decimal place
# apply the round() function 
master_df['Profit'] = master_df['Profit'].apply(lambda x: round(x, 0))
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 2  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 3  Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04              27
# 4  Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05              35
#
#    Profit  Shipping_Cost  Product_Base_Margin      ...       Product_Category  \
# 0   -30.0           3.60                 0.56      ...        OFFICE SUPPLIES
# 1  1149.0           2.50                 0.59      ...             TECHNOLOGY
# 2   -48.0           6.15                 0.37      ...        OFFICE SUPPLIES
# 3    23.0           3.37                 0.57      ...        OFFICE SUPPLIES
# 4   -18.0           3.98                 0.56      ...        OFFICE SUPPLIES
#
#             Product_Sub_Category Order_ID_x    Ship_Mode   Ship_Date  \
# 0  SCISSORS, RULERS AND TRIMMERS      36262  REGULAR AIR  28-07-2010
# 1   TELEPHONES AND COMMUNICATION      36262  EXPRESS AIR  27-07-2010
# 2                          PAPER      36262  EXPRESS AIR  28-07-2010
# 3  SCISSORS, RULERS AND TRIMMERS      37863  REGULAR AIR  26-02-2011
# 4  SCISSORS, RULERS AND TRIMMERS      53026  REGULAR AIR  03-03-2012
#
#   Order_ID_y  Order_Date Order_Priority isProfitable  is_profitable
# 0      36262  27-07-2010  NOT SPECIFIED        False          False
# 1      36262  27-07-2010  NOT SPECIFIED         True           True
# 2      36262  27-07-2010  NOT SPECIFIED        False          False
# 3      37863  24-02-2011           HIGH         True           True
# 4      53026  26-02-2012            LOW        False          False
#
# [5 rows x 24 columns]

# %% [markdown]
# You sometimes need to create new columns using existing columns, for instance, say you want a column ```Profit / Order_Quantity```.

# %%
# Creating a column Profit / Order_Quantity
master_df['profit_per_qty'] = master_df['Profit'] / master_df['Order_Quantity']
master_df.head()
master_df.loc[:,['profit_per_qty']]
# Out:
#       profit_per_qty
# 0          -1.304348
# 1          44.192308
# 2          -2.086957
# 3           0.851852
# 4          -0.514286
# 5           1.823529
# 6          -3.291667
# 7          13.520000
# 8          -1.555556
# 9          -2.500000
# 10          0.632653
# 11         -0.176471
# 12          2.264706
# 13        -14.500000
# 14         -2.777778
# 15          0.051282
# 16         -1.333333
# 17          0.100000
# 18         -2.482759
# 19          0.125000
# 20         -4.000000
# 21        -26.055556
# 22         -2.928571
# 23         -1.674419
# 24          1.600000
# 25         11.000000
# 26         -4.777778
# 27          0.062500
# 28         -5.833333
# 29       -293.333333
# ...              ...
# 8369        2.250000
# 8370       -1.277778
# 8371        3.050000
# 8372        3.724138
# 8373       24.000000
# 8374      -43.083333
# 8375       59.319149
# 8376      -21.920000
# 8377      -51.857143
# 8378       -9.736842
# 8379      -28.543478
# 8380      144.589744
# 8381      -47.000000
# 8382      -10.217391
# 8383    -1012.000000
# 8384      -19.315789
# 8385     -202.200000
# 8386        7.303030
# 8387      260.183673
# 8388     -184.400000
# 8389       43.029412
# 8390       65.333333
# 8391      179.896552
# 8392   -11769.000000
# 8393       35.625000
# 8394       49.973684
# 8395     -153.034483
# 8396       -9.475000
# 8397     -245.000000
# 8398      -49.000000
#
# [8399 rows x 1 columns]

# %% [markdown]
# ### Pivot Tables
#
# You may want to use pandas pivot tables as an alternative to ```groupby()```. They provide Excel-like functionalities to create aggregate tables.

# %%
# Read documentation
help(pd.DataFrame.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.frame:
#
# pivot_table(self, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')
#     Create a spreadsheet-style pivot table as a DataFrame. The levels in
#     the pivot table will be stored in MultiIndex objects (hierarchical
#     indexes) on the index and columns of the result DataFrame
#
#     Parameters
#     ----------
#     values : column to aggregate, optional
#     index : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table index.  If an array is passed,
#         it is being used as the same manner as column values.
#     columns : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table column.  If an array is passed,
#         it is being used as the same manner as column values.
#     aggfunc : function, list of functions, dict, default numpy.mean
#         If list of functions passed, the resulting pivot table will have
#         hierarchical columns whose top level are the function names
#         (inferred from the function objects themselves)
#         If dict is passed, the key is column to aggregate and value
#         is function or list of functions
#     fill_value : scalar, default None
#         Value to replace missing values with
#     margins : boolean, default False
#         Add all row / columns (e.g. for subtotal / grand totals)
#     dropna : boolean, default True
#         Do not include columns whose entries are all NaN
#     margins_name : string, default 'All'
#         Name of the row / column that will contain the totals
#         when margins is True.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
#     ...                          "bar", "bar", "bar", "bar"],
#     ...                    "B": ["one", "one", "one", "two", "two",
#     ...                          "one", "one", "two", "two"],
#     ...                    "C": ["small", "large", "large", "small",
#     ...                          "small", "large", "small", "small",
#     ...                          "large"],
#     ...                    "D": [1, 2, 2, 3, 3, 4, 5, 6, 7]})
#     >>> df
#          A    B      C  D
#     0  foo  one  small  1
#     1  foo  one  large  2
#     2  foo  one  large  2
#     3  foo  two  small  3
#     4  foo  two  small  3
#     5  bar  one  large  4
#     6  bar  one  small  5
#     7  bar  two  small  6
#     8  bar  two  large  7
#
#     >>> table = pivot_table(df, values='D', index=['A', 'B'],
#     ...                     columns=['C'], aggfunc=np.sum)
#     >>> table
#     C        large  small
#     A   B
#     bar one    4.0    5.0
#         two    7.0    6.0
#     foo one    4.0    1.0
#         two    NaN    6.0
#
#     >>> table = pivot_table(df, values='D', index=['A', 'B'],
#     ...                     columns=['C'], aggfunc=np.sum)
#     >>> table
#     C        large  small
#     A   B
#     bar one    4.0    5.0
#         two    7.0    6.0
#     foo one    4.0    1.0
#         two    NaN    6.0
#
#     >>> table = pivot_table(df, values=['D', 'E'], index=['A', 'C'],
#     ...                     aggfunc={'D': np.mean,
#     ...                              'E': [min, max, np.mean]})
#     >>> table
#                       D   E
#                    mean max median min
#     A   C
#     bar large  5.500000  16   14.5  13
#         small  5.500000  15   14.5  14
#     foo large  2.000000  10    9.5   9
#         small  2.333333  12   11.0   8
#
#     Returns
#     -------
#     table : DataFrame
#
#     See also
#     --------
#     DataFrame.pivot : pivot without aggregation that can handle
#         non-numeric data

# %% [markdown]
# The general syntax is ```pivot_table(data, values=None, index=None, columns=None, aggfunc='mean', ...)```.
# * ```data``` is a dataframe
# * ```values``` contains the column to aggregate
# * ```index``` is the row in the pivot table
# * ```columns``` contains the columns you want in the pivot table
# * ```aggfunc``` is the aggregate function
#
# Let's see some examples.

# %%
# E.g. Compare average Sales across customer segments
master_df.pivot_table(values = 'Sales', index = 'Customer_Segment', aggfunc = 'mean')
# Out:
#                         Sales
# Customer_Segment
# CONSUMER          1857.859965
# CORPORATE         1787.680389
# HOME OFFICE       1754.312931
# SMALL BUSINESS    1698.124841

# %%
# E.g. compare total number of profitable orders across regions
# Note that since is_profitable is 1/0, we can directly compute the sum
master_df.pivot_table(values = 'is_profitable', index = 'Region', aggfunc = 'sum')
# Out:
#                        is_profitable
# Region
# ATLANTIC                       544.0
# NORTHWEST TERRITORIES          194.0
# NUNAVUT                         38.0
# ONTARIO                        916.0
# PRARIE                         852.0
# QUEBEC                         360.0
# WEST                           969.0
# YUKON                          262.0

# %%
# Grouping by both rows and columns
# Compare the total profit across product categories and customer segments
# Since there are two categorical variables, we use both rows (index) and columns
master_df.pivot_table(values = 'Profit', 
                      index = 'Product_Category', 
                      columns = 'Customer_Segment', 
                      aggfunc = 'sum')
# Out:
# Customer_Segment  CONSUMER  CORPORATE  HOME OFFICE  SMALL BUSINESS
# Product_Category
# FURNITURE          42728.5    22008.3      23978.6         28717.5
# OFFICE SUPPLIES    88532.4   203038.8     121145.6        105306.8
# TECHNOLOGY        156700.1   374701.1     173230.6        181684.1

# %% [markdown]
# You don't necessarily need to specify all four arguments, since ```pivot_table()``` has some smart defaults. For instance, if you just provide ```columns```, it will compute the **mean of all the numeric columns** across each column. For e.g.:

# %%
# Computes the mean of all numeric columns across categories
# Notice that the means of Order_IDs are meaningless
master_df.pivot_table(columns = 'Product_Category')
# Out:
# Product_Category        FURNITURE  OFFICE SUPPLIES    TECHNOLOGY
# Discount                 0.049287         0.050230      0.048746
# Order_ID_x           30128.711717     30128.122560  29464.891525
# Order_ID_y           30128.711717     30128.122560  29464.891525
# Order_Quantity          25.709977        25.656833     25.266344
# Product_Base_Margin      0.598555         0.461270      0.556305
# Profit                  68.116531       112.369544    429.208668
# Sales                 3003.822820       814.048178   2897.941008
# Shipping_Cost           30.883811         7.829829      8.954886
# is_profitable            0.465197         0.466161      0.573366
# profit_per_qty          -3.607020         1.736175    -52.274216
